# %% [markdown]
# ## Exercise:
# Find a dataset on your computer (or download one from Kaggle Datasets) and read it into pandas using read_table, modifying the default arguments as necessary
#
# I will use this Kaggle data file:
# https://www.kaggle.com/datasets/andrewmvd/sp-500-stocks?resource=download

# %%
import pandas as pd

# %%
pd.read_table('data/sp500_companies.csv')
# Out:
#     Exchange,Symbol,Shortname,Longname,Sector,Industry,Currentprice,Marketcap,Ebitda,Revenuegrowth,City,State,Country,Fulltimeemployees,Longbusinesssummary,Weight
# 0    NMS,MSFT,Microsoft Corporation,Microsoft Corpo...
# 1    NMS,AAPL,Apple Inc.,Apple Inc.,Technology,Cons...
# 2    NMS,NVDA,NVIDIA Corporation,NVIDIA Corporation...
# 3    NMS,GOOG,Alphabet Inc.,Alphabet Inc.,Communica...
# 4    NMS,GOOGL,Alphabet Inc.,Alphabet Inc.,Communic...
# ..                                                 ...
# 499  NMS,ETSY,"Etsy, Inc.","Etsy, Inc.",Consumer Cy...
# 500  NYQ,IVZ,Invesco Ltd,Invesco Ltd.,Financial Ser...
# 501  NYQ,RHI,Robert Half Inc.,Robert Half Inc.,Indu...
# 502  NYQ,NCLH,Norwegian Cruise Line Holdings ,Norwe...
# 503  NYQ,CMA,Comerica Incorporated,Comerica Incorpo...
#
# [504 rows x 1 columns]

# %%
pd.read_table('data/sp500_companies.csv', sep=",")
# Out:
#     Exchange Symbol                        Shortname  \
# 0        NMS   MSFT            Microsoft Corporation
# 1        NMS   AAPL                       Apple Inc.
# 2        NMS   NVDA               NVIDIA Corporation
# 3        NMS   GOOG                    Alphabet Inc.
# 4        NMS  GOOGL                    Alphabet Inc.
# ..       ...    ...                              ...
# 498      NMS   ETSY                       Etsy, Inc.
# 499      NYQ    IVZ                      Invesco Ltd
# 500      NYQ    RHI                 Robert Half Inc.
# 501      NYQ   NCLH  Norwegian Cruise Line Holdings
# 502      NYQ    CMA            Comerica Incorporated
#
#                                 Longname                  Sector  \
# 0                  Microsoft Corporation              Technology
# 1                             Apple Inc.              Technology
# 2                     NVIDIA Corporation              Technology
# ...

# %%
orders = pd.read_table('http://bit.ly/chiporders')
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
pd.read_table('http://bit.ly/movieusers')
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
pd.read_table('http://bit.ly/movieusers', sep="|")
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# ..   ...  .. ..            ...    ...
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841
#
# [942 rows x 5 columns]

# %%
pd.read_table('http://bit.ly/movieusers', sep="|", header=None)
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
user_cols = ["user_id", "age", "gender", "occupation", "zip_code"]
users = pd.read_table('http://bit.ly/movieusers', sep="|", header=None, names=user_cols)

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213
